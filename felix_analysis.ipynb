# %%
from utils.DataEngine import DataEngine

# %%
data_engine = DataEngine("data2023")

# %%
data_engine.data
# Out:
# {'round_1': {'price_df':        day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
#   0       -2          0  BANANAS         4997            26          NaN
#   1       -2          0   PEARLS         9996             1       9995.0
#   2       -2        100  BANANAS         4997            20          NaN
#   3       -2        100   PEARLS        10000             5       9995.0
#   4       -2        200   PEARLS         9996             1       9995.0
#   ...    ...        ...      ...          ...           ...          ...
#   59995    0    2999700  BANANAS         4875             1       4870.0
#   59996    0    2999800   PEARLS         9995            27          NaN
#   59997    0    2999800  BANANAS         4869            27          NaN
#   59998    0    2999900   PEARLS         9996             2       9995.0
#   59999    0    2999900  BANANAS         4870            23          NaN
#
# ...
