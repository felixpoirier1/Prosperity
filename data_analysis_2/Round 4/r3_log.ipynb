# %%
import pandas as pd

# %%
l = []
with open("../../logs/message.csv", "r") as f:
    file = f.read().split(r"\n")
    for line in file:
        l.append(line.split(";"))
    #file = file.replace(r"\\n", "\n")

# %%
df = pd.DataFrame(l[1:], columns = l[0])

# %%
float_cols = df.columns[3:]
#df[[df.columns]]
df[float_cols] = df[float_cols].replace("", None).astype(float)
df[df.columns[:2]] = df[df.columns[:2]].astype(int)

# %%
df
# Out:
#        "day  timestamp         product  bid_price_1  bid_volume_1  \
# 0         4          0       STARFRUIT       4906.0           3.0
# 1         4          0    STRAWBERRIES       3957.0         272.0
# 2         4          0         COCONUT       9883.0         136.0
# 3         4          0  COCONUT_COUPON        574.0          38.0
# 4         4          0           ROSES      13712.0          53.0
# ...     ...        ...             ...          ...           ...
# 89995     4     999900         ORCHIDS       1145.0           8.0
# 89996     4     999900     GIFT_BASKET      69792.0           1.0
# 89997     4     999900         COCONUT       9860.0         104.0
# 89998     4     999900  COCONUT_COUPON        581.0          41.0
# 89999     4     999900           ROSES      13719.0          30.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0           4905.0          26.0          NaN           NaN       4912.0
# ...

# %%
df.to_csv("../../logs/round4_results.csv", index=False)
