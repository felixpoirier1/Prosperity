# %%
import sys
import json
sys.path.append('..')

from utils.DataEngine import LogInterpreter

# %%
logger = LogInterpreter('../logs/round_1_final.log')

# %%
sandbox = logger.getSandboxLogs()
# Out:
# [{
#   "sandboxLog": "",
#   "lambdaLog": "[[0,\"\",[[\"STARFRUIT\",\"STARFRUIT\",1],[\"AMETHYSTS\",\"AMETHYSTS\",1]],{\"AMETHYSTS\":[{\"9998\":9,\"9995\":23},{\"10005\":-23}],\"STARFRUIT\":[{\"5036\":23},{\"5043\":-23}]},[],[],{},[{},{}]],[[\"AMETHYSTS\",9998,20],[\"AMETHYSTS\",10004,-20],[\"STARFRUIT\",5037,20],[\"STARFRUIT\",5042,-20]],0,\"{\\\"position\\\": {\\\"STARFRUIT\\\": 0, \\\"AMETHYSTS\\\": 0}, \\\"cpnl\\\": {\\\"py/object\\\": \\\"collections.defaultdict\\\", \\\"default_factory\\\": {\\\"py/object\\\": \\\"jsonpickle.handlers.CloneFactory\\\", \\\"exemplar\\\": 0}}, \\\"sf_cache\\\": [5039.5], \\\"POSITION_LIMIT\\\": {\\\"STARFRUIT\\\": 20, \\\"AMETHYSTS\\\": 20}, \\\"sf_params\\\": [0.08442609, 0.18264657, 0.7329293]}\",\"Empty trader data\\n\"]",
#   "timestamp": 0
# },
# {
#   "sandboxLog": "",
# ...

# %%
for dict_ in sandbox:

    if dict_["sandboxLog"] != "":
        print(dict_["sandboxLog"])
