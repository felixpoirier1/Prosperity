# %% [markdown]
# <div style="text-align: right"> IMC Prosperity </div>
#
# <left> Team Tempname1 </left>
# <br>
# <left>February 2024</left>
#
# <h2><center> Round 1: Data Exploration </center></h2>

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %% [markdown]
# The codes below separately load all csv files as a dataframes, rename / expand columns, and drop the original column (where everything is separated by semicolons in a single column). A column 'day' has also been added to all 3 trades dataframes.

# %%
prices_0 = pd.read_csv("prices_round_1_day_0.csv")
prices_0[['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3',
          'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3',
          'mid_price', 'profit_and_loss']] = prices_0['day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss'].str.split(';', expand=True)
prices_0.drop(columns=['day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss'], inplace=True)
prices_0
# Out:
#       day timestamp    product bid_price_1 bid_volume_1 bid_price_2  \
# 0       0         0  AMETHYSTS        9998            1        9995
# 1       0         0  STARFRUIT        5036           30
# 2       0       100  AMETHYSTS        9996            1        9995
# 3       0       100  STARFRUIT        5041            4        5037
# 4       0       200  AMETHYSTS        9996            1        9995
# ...    ..       ...        ...         ...          ...         ...
# 19995   0    999700  STARFRUIT        5053            1        5048
# 19996   0    999800  STARFRUIT        5047           27
# 19997   0    999800  AMETHYSTS        9995           27
# 19998   0    999900  STARFRUIT        5048            2        5047
# 19999   0    999900  AMETHYSTS        9996            2        9995
#
#       bid_volume_2 bid_price_3 bid_volume_3 ask_price_1 ask_volume_1  \
# 0               30                                10005           30
# ...

# %%
prices_1 = pd.read_csv("prices_round_1_day_-1.csv")
prices_1[['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3',
          'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3',
          'mid_price', 'profit_and_loss']] = prices_1['day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss'].str.split(';', expand=True)
prices_1.drop(columns=['day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss'], inplace=True)

# %%
prices_2 = pd.read_csv("prices_round_1_day_-2.csv")
prices_2[['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3',
          'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3',
          'mid_price', 'profit_and_loss']] = prices_2['day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss'].str.split(';', expand=True)
prices_2.drop(columns=['day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss'], inplace=True)

# %%
trades_0 = pd.read_csv('trades_round_1_day_0_nn.csv')
trades_0[['timestamp', 'buyer', 'seller', 'symbol', 'currency', 'price', 'quantity']] = trades_0['timestamp;buyer;seller;symbol;currency;price;quantity'].str.split(';', expand=True)
trades_0.drop(columns=['timestamp;buyer;seller;symbol;currency;price;quantity'], inplace=True)
trades_0.insert(0, 'day', '0')
trades_0
# Out:
#      day timestamp buyer seller     symbol   currency    price quantity
# 0      0       100               STARFRUIT  SEASHELLS   5041.0        4
# 1      0       100               AMETHYSTS  SEASHELLS  10002.0        1
# 2      0       300               AMETHYSTS  SEASHELLS   9998.0        2
# 3      0       300               AMETHYSTS  SEASHELLS   9998.0        1
# 4      0       300               STARFRUIT  SEASHELLS   5037.0        6
# ...   ..       ...   ...    ...        ...        ...      ...      ...
# 5312   0    998800               STARFRUIT  SEASHELLS   5050.0        1
# 5313   0    998800               AMETHYSTS  SEASHELLS  10002.0        1
# 5314   0    999500               AMETHYSTS  SEASHELLS   9995.0        2
# 5315   0    999500               STARFRUIT  SEASHELLS   5049.0        2
# 5316   0    999600               STARFRUIT  SEASHELLS   5048.0        1
#
# [5317 rows x 8 columns]

# %%
trades_1 = pd.read_csv('trades_round_1_day_-1_nn.csv')
trades_1[['timestamp', 'buyer', 'seller', 'symbol', 'currency', 'price', 'quantity']] = trades_1['timestamp;buyer;seller;symbol;currency;price;quantity'].str.split(';', expand=True)
trades_1.drop(columns=['timestamp;buyer;seller;symbol;currency;price;quantity'], inplace=True)
trades_1.insert(0, 'day', '-1')

# %%
trades_2 = pd.read_csv('trades_round_1_day_-2_nn.csv')
trades_2[['timestamp', 'buyer', 'seller', 'symbol', 'currency', 'price', 'quantity']] = trades_2['timestamp;buyer;seller;symbol;currency;price;quantity'].str.split(';', expand=True)
trades_2.drop(columns=['timestamp;buyer;seller;symbol;currency;price;quantity'], inplace=True)
trades_2.insert(0, 'day', '-2')

# %% [markdown]
# ### Organize Data

# %% [markdown]
# The codes below first concatinate all 3 dataframes for price and trades into a single dataframe and then create separate dataframes for amethysts and starfruit respectively. Indexes are also reset. Additionally, columns are converted from object to numeric data types.

# %%
prices = pd.concat([prices_2, prices_1, prices_0], ignore_index=True)

prices_columns_to_convert = ['day', 'timestamp', 'bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2', 'bid_price_3',
          'bid_volume_3', 'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3',
          'mid_price', 'profit_and_loss']
for col in prices_columns_to_convert:
    prices[col] = pd.to_numeric(prices[col], errors='coerce')
    
prices
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -2          0  AMETHYSTS         9996             1       9995.0
# 1       -2          0  STARFRUIT         4997            26          NaN
# 2       -2        100  AMETHYSTS        10000             5       9995.0
# 3       -2        100  STARFRUIT         5000             5       4998.0
# 4       -2        200  STARFRUIT         4997             1       4996.0
# ...    ...        ...        ...          ...           ...          ...
# 59995    0     999700  STARFRUIT         5053             1       5048.0
# 59996    0     999800  STARFRUIT         5047            27          NaN
# 59997    0     999800  AMETHYSTS         9995            27          NaN
# 59998    0     999900  STARFRUIT         5048             2       5047.0
# 59999    0     999900  AMETHYSTS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
amethysts_prices = prices[prices['product'] == 'AMETHYSTS']
amethysts_prices.reset_index(drop=True, inplace=True)
amethysts_prices
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -2          0  AMETHYSTS         9996             1       9995.0
# 1       -2        100  AMETHYSTS        10000             5       9995.0
# 2       -2        200  AMETHYSTS         9996             1       9995.0
# 3       -2        300  AMETHYSTS         9996             1       9995.0
# 4       -2        400  AMETHYSTS         9995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# 29995    0     999500  AMETHYSTS         9995            28          NaN
# 29996    0     999600  AMETHYSTS         9996             2       9995.0
# 29997    0     999700  AMETHYSTS         9996             2       9995.0
# 29998    0     999800  AMETHYSTS         9995            27          NaN
# 29999    0     999900  AMETHYSTS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
starfruit_prices = prices[prices['product'] == 'STARFRUIT']
starfruit_prices.reset_index(drop=True, inplace=True)
starfruit_prices
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -2          0  STARFRUIT         4997            26          NaN
# 1       -2        100  STARFRUIT         5000             5       4998.0
# 2       -2        200  STARFRUIT         4997             1       4996.0
# 3       -2        300  STARFRUIT         4996            27          NaN
# 4       -2        400  STARFRUIT         4995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# 29995    0     999500  STARFRUIT         5049            28          NaN
# 29996    0     999600  STARFRUIT         5048             9       5047.0
# 29997    0     999700  STARFRUIT         5053             1       5048.0
# 29998    0     999800  STARFRUIT         5047            27          NaN
# 29999    0     999900  STARFRUIT         5048             2       5047.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
trades = pd.concat([trades_2, trades_1, trades_0], ignore_index=True)

trades_columns_to_convert = ['day', 'timestamp', 'price', 'quantity']
for col in trades_columns_to_convert:
    trades[col] = pd.to_numeric(trades[col], errors='coerce')
    
trades
# Out:
#        day  timestamp buyer seller     symbol   currency    price  quantity
# 0       -2          0               AMETHYSTS  SEASHELLS   9996.0         1
# 1       -2          0               STARFRUIT  SEASHELLS   5003.0         1
# 2       -2          0               AMETHYSTS  SEASHELLS   9996.0         1
# 3       -2        100               STARFRUIT  SEASHELLS   5004.0         6
# 4       -2        900               STARFRUIT  SEASHELLS   5001.0         2
# ...    ...        ...   ...    ...        ...        ...      ...       ...
# 16145    0     998800               STARFRUIT  SEASHELLS   5050.0         1
# 16146    0     998800               AMETHYSTS  SEASHELLS  10002.0         1
# 16147    0     999500               AMETHYSTS  SEASHELLS   9995.0         2
# 16148    0     999500               STARFRUIT  SEASHELLS   5049.0         2
# 16149    0     999600               STARFRUIT  SEASHELLS   5048.0         1
#
# [16150 rows x 8 columns]

# %%
amethysts_trades = trades[trades['symbol'] == 'AMETHYSTS']
amethysts_trades.reset_index(drop=True, inplace=True)
amethysts_trades
# Out:
#       day  timestamp buyer seller     symbol   currency    price  quantity
# 0      -2          0               AMETHYSTS  SEASHELLS   9996.0         1
# 1      -2          0               AMETHYSTS  SEASHELLS   9996.0         1
# 2      -2       1500               AMETHYSTS  SEASHELLS  10004.0         1
# 3      -2       2500               AMETHYSTS  SEASHELLS   9998.0         1
# 4      -2       3200               AMETHYSTS  SEASHELLS   9996.0         1
# ...   ...        ...   ...    ...        ...        ...      ...       ...
# 7230    0     997600               AMETHYSTS  SEASHELLS  10002.0         4
# 7231    0     997700               AMETHYSTS  SEASHELLS  10002.0         1
# 7232    0     998400               AMETHYSTS  SEASHELLS  10002.0         4
# 7233    0     998800               AMETHYSTS  SEASHELLS  10002.0         1
# 7234    0     999500               AMETHYSTS  SEASHELLS   9995.0         2
#
# [7235 rows x 8 columns]

# %%
starfruit_trades = trades[trades['symbol'] == 'STARFRUIT']
starfruit_trades.reset_index(drop=True, inplace=True)
starfruit_trades
# Out:
#       day  timestamp buyer seller     symbol   currency   price  quantity
# 0      -2          0               STARFRUIT  SEASHELLS  5003.0         1
# 1      -2        100               STARFRUIT  SEASHELLS  5004.0         6
# 2      -2        900               STARFRUIT  SEASHELLS  5001.0         2
# 3      -2       1000               STARFRUIT  SEASHELLS  4997.0         2
# 4      -2       1100               STARFRUIT  SEASHELLS  4997.0         1
# ...   ...        ...   ...    ...        ...        ...     ...       ...
# 8910    0     998500               STARFRUIT  SEASHELLS  5050.0         3
# 8911    0     998700               STARFRUIT  SEASHELLS  5055.0         1
# 8912    0     998800               STARFRUIT  SEASHELLS  5050.0         1
# 8913    0     999500               STARFRUIT  SEASHELLS  5049.0         2
# 8914    0     999600               STARFRUIT  SEASHELLS  5048.0         1
#
# [8915 rows x 8 columns]

# %% [markdown]
# ### Summarize Data

# %% [markdown]
# The codes below describe prices and trades data for amethysts and starfruit.

# %%
amethysts_prices_describe = amethysts_prices.describe()
amethysts_prices_describe
# Out:
#                day      timestamp   bid_price_1  bid_volume_1   bid_price_2  \
# count  30000.00000   30000.000000  30000.000000  30000.000000  22311.000000
# mean      -1.00000  499950.000000   9996.609633      8.218933   9995.290395
# std        0.81651  288679.944524      1.937861     10.155552      0.634420
# min       -2.00000       0.000000   9995.000000      0.000000   9995.000000
# 25%       -2.00000  249975.000000   9995.000000      1.000000   9995.000000
# 50%       -1.00000  499950.000000   9996.000000      2.000000   9995.000000
# 75%        0.00000  749925.000000   9996.000000     20.000000   9995.000000
# max        0.00000  999900.000000  10002.000000     30.000000  10000.000000
#
#        bid_volume_2  bid_price_3  bid_volume_3   ask_price_1  ask_volume_1  \
# count  22311.000000  5141.000000   5141.000000  30000.000000  30000.000000
# mean      19.714939  9995.083252     23.099981  10003.383467      8.212767
# ...

# %%
starfruit_prices_describe = starfruit_prices.describe()
starfruit_prices_describe
# Out:
#                day      timestamp   bid_price_1  bid_volume_1   bid_price_2  \
# count  30000.00000   30000.000000  30000.000000  30000.000000  11281.000000
# mean      -1.00000  499950.000000   5034.725867     17.231233   5033.924652
# std        0.81651  288679.944524     32.295106     11.463485     32.358842
# min       -2.00000       0.000000   4948.000000      1.000000   4948.000000
# 25%       -2.00000  249975.000000   5025.000000      3.000000   5024.000000
# 50%       -1.00000  499950.000000   5045.000000     23.000000   5045.000000
# 75%        0.00000  749925.000000   5056.000000     27.000000   5055.000000
# max        0.00000  999900.000000   5093.000000     32.000000   5092.000000
#
#        bid_volume_2  bid_price_3  bid_volume_3   ask_price_1  ask_volume_1  \
# count  11281.000000  1257.000000   1257.000000  30000.000000  30000.000000
# mean      23.089354  5034.486078     24.445505   5040.125467     17.766700
# ...

# %%
amethysts_trades_describe = amethysts_trades.describe()
amethysts_trades_describe
# Out:
#                day      timestamp         price     quantity
# count  7235.000000    7235.000000   7235.000000  7235.000000
# mean     -1.005529  496217.401520   9999.968487     2.104630
# std       0.818620  287667.575521      3.151743     2.002825
# min      -2.000000       0.000000   9995.000000     0.000000
# 25%      -2.000000  245950.000000   9998.000000     1.000000
# 50%      -1.000000  494300.000000   9998.000000     1.000000
# 75%       0.000000  742700.000000  10002.000000     2.000000
# max       0.000000  999800.000000  10005.000000    12.000000

# %%
starfruit_trades_describe = starfruit_trades.describe()
starfruit_trades_describe
# Out:
#                day      timestamp        price     quantity
# count  8915.000000    8915.000000  8915.000000  8915.000000
# mean     -1.011890  498834.761638  5036.637128     2.803814
# std       0.815677  289212.047502    32.042691     3.246196
# min      -2.000000       0.000000  4949.000000     0.000000
# 25%      -2.000000  246500.000000  5026.000000     1.000000
# 50%      -1.000000  502500.000000  5047.000000     1.000000
# 75%       0.000000  744650.000000  5058.000000     3.000000
# max       0.000000  999900.000000  5094.000000    15.000000

# %% [markdown]
# ### Visualize Data

# %%
plt.plot(amethysts_prices.index, amethysts_prices['bid_price_1'], label='Bid Price 1')

plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Bid Price 1')
plt.legend()

plt.show()
